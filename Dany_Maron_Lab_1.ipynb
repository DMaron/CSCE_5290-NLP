# %% [markdown]
# <a href="https://colab.research.google.com/github/DMaron/CSCE_5290-NLP/blob/main/Dany_Maron_Lab_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Import libraries
import urllib.request
from bs4 import BeautifulSoup
import nltk

from nltk.corpus import stopwords

# %%
# Download stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# True

# %%
# Read SpaceX Wikipedia page
response = urllib.request.urlopen('https://en.wikipedia.org/wiki/SpaceX')
html = response.read()

# Apply BeautifulSoup
soup = BeautifulSoup(html,"html5lib")
text = soup.get_text(strip=True)

# %%
# Count tokens
tokens = [t for t in text.split()]
freq = nltk.FreqDist(tokens)

# %%
# Plot graph WITHOUT removing the stopwords
freq.plot(10, cumulative='False')

# %%
# Remove stopwords
clean_tokens = tokens[:]

sr = stopwords.words('english')

for token in tokens:
  if token in stopwords.words('english'):
    clean_tokens.remove(token)

freq = nltk.FreqDist(clean_tokens)

# %%
# Print graph after removing stopwords
freq.plot(10, cumulative='False')

# %%
freq.plot(10, cumulative=0)

# %%
frequency = []
for key,val in freq.items():
  frequency.append(val)

# %%
import matplotlib.pyplot as plt

plt.hist(frequency, bins=100)
plt.show()
